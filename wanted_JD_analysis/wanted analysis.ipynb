# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/USER/Desktop/personal_project/wanted_JD_analysis/wanted_data_prep.csv', encoding = 'utf-8-sig')
df.head(5)

# 한글 폰트깨짐을 위한 기본 세팅법
plt.rcParams['font.family'] = 'Malgun Gothic'
font_path = 'C:/Windows/Fonts/malgun.ttf'

# %%
df.head(5)
# Out:
#              company_name industry    dt_ym                 ct_1st  \
# 0  지니웍스(Genieworks, Inc.)  IT, 컨텐츠  2024-01  Management & Business
# 1  지니웍스(Genieworks, Inc.)  IT, 컨텐츠  2024-01                     IT
# 2              다큐브(daquv)  IT, 컨텐츠  2024-01  Management & Business
# 3  지니웍스(Genieworks, Inc.)  IT, 컨텐츠  2024-01                     IT
# 4            위메이드(WEMADE)  IT, 컨텐츠  2024-01  Management & Business
#
#             ct_2nd                                       job_req_noun  \
# 0  Service Planner  ['커머스', '쇼핑몰', '분야', '전반', '프론트', '백오피스', '기획'...
# 1   Java Developer  ['개발', '경력', '구축', '이용', '개발', '디자이너', '개발', '...
# 2  Project Manager             ['경력', '자', '이해관계자', '소통', '협의', '보신']
# 3   Java Developer  ['개발', '경력', '기반', '서버', '개발', '템플릿', '엔진', '이...
# 4  Project Manager  ['게임', '업계', '사업', '팀', '경력', '엑셀', '파워포인트', '...
#
#                                         job_add_noun  \
# 0      ['커머스', '쇼핑몰', '경력', '작성', '웹', '에이전시', '분야']
# ...

# %% [markdown]
# # 기본 시각화

# %% [markdown]
# ## 산업군 채용 건수 시각화

# %%
plt.figure(figsize = (25, 10))
# df 값 주고, index를 주면 오름차순 정렬 가능
sns.countplot(x='industry', data = df, order = df['industry'].value_counts().index)
plt.grid(True)
plt.title('산업군에 따른 공고 수')
plt.show()

# %% [markdown]
# - IT, 컨텐츠 관련 회사가 대다수, 그 이후 판매/유통, 제조가 뒤를 따름
# - Wanted는 대부분 테크 회사가 많이 이용하고 있음을 유추 가능,

# %% [markdown]
# ## 대분류에 따른 건수 시각화

# %%
plt.figure(figsize = (25, 10))
# df 값 주고, index를 주면 오름차순 정렬 가능
sns.countplot(x='ct_1st', data = df, order = df['ct_1st'].value_counts().index)
plt.xticks(rotation = 30)
plt.grid(True)
plt.title('채용 공고 분류에 따른 공고 수')
plt.show()

# %% [markdown]
# - IT, 경영관리, 마케팅, 디자인, 세일즈, 고객서비스 순서로 많으며, 그 이후로는 인사, 미디어가 잇고 있음
# - IT, 컨텐츠 관련 회사답게 IT 직군이 대부분의 양을 차지하고 있으나 경영 관련 직군이 2위인 부분을 눈여겨 볼 수 있을 것으로 보임

# %%
df['ct_1st'].value_counts().index
# Out:
# Index(['IT', 'Management & Business', 'Marketing & Advertising', 'Design',
#        'Sales', 'Customer Service', 'HR', 'Media & Communication',
#        'Manufacturing', 'Finance', 'Engineering', 'Bio', 'Logistics& Trade',
#        'Game Production', 'Education', 'Law', 'Construction', 'F&B'],
#       dtype='object')

# %% [markdown]
# ### 소분류에 따른 건수 시각화 - IT

# %%
cur_df = df.loc[df.ct_1st == 'IT']
plt.figure(figsize = (25, 10))
# df 값 주고, index를 주면 오름차순 정렬 가능
sns.countplot(x='ct_2nd', data = cur_df, order = cur_df['ct_2nd'].value_counts().index)
plt.xticks(rotation = 30)
plt.grid(True)
plt.title('IT 채용 공고 분류에 따른 공고 수')
plt.show()

# %%
cur_df['ct_2nd'].value_counts().index
# Out:
# Index(['Front-end Engineer', 'Java Developer', 'Back-end Engineer',
#        'Data Engineer', 'System', 'Android Developer', 'QA', 'Web Developer',
#        'Embedded Developer', 'DevOps / System Admin', 'C', 'Software Engineer',
#        'Python Developer', 'Security Engineer', '.NET Developer',
#        'Product Manager', 'Hardware Engineer', 'Technical Support',
#        'Development Manager', 'Machine Learning Engineer', 'Data Scientist',
#        'iOS Developer', 'Database Administrator', 'Web Publisher',
#        'Node.js Developer', 'Blockchain Platform Engineer',
#        'Graphics Engineer', 'ERP Consultant', 'PHP Developer',
#        'Big Data Engineer', 'CTO', 'Cross-platform App Developer', 'Video',
#        'BI Engineer', 'VR Engineer'],
#       dtype='object')

# %% [markdown]
# - 프론트, 자바, 백 엔드가 대다수를 차지하고 있음
# - 의외로, QA가 높은 순위를 차지하고 있음
# - 국내 시장 환경에 맞게, 모바일은 iOS보다는 Android가 더 대세임을 확인가능
# - 데이터 관련 분야는 데이터 엔지니어이외 수요가 많지 않음

# %%
cur_df = df.loc[df.ct_1st == 'Management & Business']
plt.figure(figsize = (25, 10))
# df 값 주고, index를 주면 오름차순 정렬 가능
sns.countplot(x='ct_2nd', data = cur_df, order = cur_df['ct_2nd'].value_counts().index)
plt.xticks(rotation = 30)
plt.grid(True)
plt.title('IT 채용 공고 분류에 따른 공고 수')
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 경영 분야는 PM. 경영지원 쪽이 가장 높은 비율을 차지

# %%
plt.figure(figsize = (25, 10))
sns.countplot(x='dt_ym', data = df, order = df['dt_ym'].value_counts().index)
plt.xticks(rotation = 30)
plt.grid(True)
plt.title('채용 공고 분류에 따른 공고 수')
plt.show()

# %% [markdown]
# - 시기에 대한 데이터는 유의미하지 않다.
#   - 공고를 새로 갱신하는 등의 방법으로 날짜가 새로 갱신되었을 수 있다.
#   - 2500개의 공고만 추출하여, 최신 2500개만 나왔을 것으로 보인다. 더 많은 양을 추출해야 날짜의 사용이 가능할 것으로 보인다.

# %% [markdown]
# # Questions
# - 시기에 따라서 주요 직군별로 채용 희망 세부 직무가 달라졌을까?
# - 대표 직무나 관심 직무를 선정, 요구 사항과 우대 사항에는 유의미한 변화가 있을까?

# %% [markdown]
# ## 직무 키워드 분석

# %% [markdown]
# ### IT 직군 분석

# %%
cur_df = df.loc[df.ct_1st == 'IT']
cur_df['ct_2nd'].value_counts().index
# Out:
# Index(['Front-end Engineer', 'Java Developer', 'Back-end Engineer',
#        'Data Engineer', 'System', 'Android Developer', 'QA', 'Web Developer',
#        'Embedded Developer', 'DevOps / System Admin', 'C', 'Software Engineer',
#        'Python Developer', 'Security Engineer', '.NET Developer',
#        'Product Manager', 'Hardware Engineer', 'Technical Support',
#        'Development Manager', 'Machine Learning Engineer', 'Data Scientist',
#        'iOS Developer', 'Database Administrator', 'Web Publisher',
#        'Node.js Developer', 'Blockchain Platform Engineer',
#        'Graphics Engineer', 'ERP Consultant', 'PHP Developer',
#        'Big Data Engineer', 'CTO', 'Cross-platform App Developer', 'Video',
#        'BI Engineer', 'VR Engineer'],
#       dtype='object')

# %% [markdown]
# 주요 3 직군인 프론트, 자바, 백엔드에 대해 분석 후 관심 분야인 데이터 사이언티스트 까지 총 4가지에 대해 분석해보자.

# %%
df_front = cur_df.loc[cur_df.ct_2nd == 'Front-end Engineer']
df_java = cur_df.loc[cur_df.ct_2nd == 'Java Developer']
df_back = cur_df.loc[cur_df.ct_2nd == 'Back-end Engineer']
df_ds = cur_df.loc[cur_df.ct_2nd == 'Data Scientist']

# %%
df_ds
# Out:
#          company_name industry    dt_ym ct_1st          ct_2nd  \
# 35      에이비일팔공(AB180)  IT, 컨텐츠  2024-01     IT  Data Scientist
# 186              투스카이  IT, 컨텐츠  2023-12     IT  Data Scientist
# 463               루먼랩  IT, 컨텐츠  2023-12     IT  Data Scientist
# 750   씨제이대한통운(CJ대한통운)   물류, 운송  2023-12     IT  Data Scientist
# 1059        에이아이더뉴트리진  IT, 컨텐츠  2023-12     IT  Data Scientist
# 1450              루먼랩  IT, 컨텐츠  2023-12     IT  Data Scientist
# 2370           엠에스홀딩스   판매, 유통  2023-10     IT  Data Scientist
# 2707       앤톡(Antock)  IT, 컨텐츠  2023-12     IT  Data Scientist
# 2790           에이젠글로벌       금융  2023-12     IT  Data Scientist
# 2960            현대캐피탈       금융  2023-12     IT  Data Scientist
# 3093               로민  IT, 컨텐츠  2023-12     IT  Data Scientist
# 3830      다비오(Dabeeo)  IT, 컨텐츠  2023-11     IT  Data Scientist
# 4296             앰버로드  IT, 컨텐츠  2023-11     IT  Data Scientist
# 4618           에스넷시스템  IT, 컨텐츠  2023-11     IT  Data Scientist
# ...

# %%
# 주의사항 여러개의 공고에 대해서 하나의 중요어휘를 만들어야 하므로 직접 만든다.
# tf-idf 직접 유도. 
import math
from ast import literal_eval

def get_tfidf(s_list, len_df):
    word_count_dict = {}
    page_count_dict = {}
    
    # step 1 .tf, df 를 세자
    for cur_list in s_list:
        cur_page_word = []
        cur_list = literal_eval(cur_list)
        for cur_word in cur_list:
            # 문제 : cur_word가 지금 리스트 형태가 아닌 문자열로 들어와버림
            if cur_word not in word_count_dict:
                # 새로 본 단어라면
                word_count_dict[cur_word] = 1
                page_count_dict[cur_word] = 1
                cur_page_word.append(cur_word)
            else:
                # 이미 봤던 단어라면
                word_count_dict[cur_word] += 1
                if cur_word not in cur_page_word:
                    cur_page_word.append(cur_word)
                    page_count_dict[cur_word] += 1
    # step 2. idf로 변경하자
    idf_dict = {}
    for cur_word in page_count_dict:
        idf_dict[cur_word] = math.log(len_df / (1 + page_count_dict[cur_word]))
    
    tf_idf_dict = {}
    for cur_word in word_count_dict:
        tf_idf_dict[cur_word] = word_count_dict[cur_word] * idf_dict[cur_word]
    
    return dict(sorted(tf_idf_dict.items(), key=lambda x : x[1], reverse = True))

# %%
front_tf_idf = get_tfidf(list(df_front.job_req_noun), len(df_front))

# %%
front_tf_idf
# Out:
# {'웹': 172.8398347045519,
#  '서비스': 139.1460086983597,
#  '개발': 137.75427668196787,
#  '경력': 134.36164824445177,
#  '기술': 129.23708198102827,
#  '협업': 120.34773675724352,
#  '프론트엔드': 119.46263244691998,
#  '활용': 118.24316036092239,
#  '기반': 111.20239419294526,
#  '커뮤니케이션': 110.39137471738937,
#  '프로젝트': 108.86265346894965,
#  '팀': 107.72944956329981,
#  '실무': 107.55420776091253,
#  '관리': 106.55467661928188,
#  '운영': 101.78861054470046,
#  '지원': 100.86351160945365,
#  '위해': 100.86351160945365,
#  '이용': 99.10500044824707,
#  '환경': 96.39762567823253,
#  '관련': 96.1386642744727,
#  '코드': 96.1386642744727,
#  '지식': 95.8015110428833,
#  '동료': 95.77962608509793,
#  '설계': 93.50103169644889,
#  '프로': 90.10722996682195,
#  '덕트': 90.10722996682195,
#  '사용자': 85.76282135875385,
#  '문제': 83.23873827572591,
#  '적극': 82.29294945704868,
#  '프레임워크': 81.22302023200976,
#  '디자인': 81.06163977487736,
#  '기본': 78.61534352587024,
#  '반응': 77.53588778317452,
#  '실력': 76.30312753981524,
# ...

# %% [markdown]
# 주요 단어에 대한 시각화를 고려 가능하다. 이 때, 가중치는 위에서 만든 tf_idf dict로 한다.

# %% [markdown]
# ### 프론트

# %%
from wordcloud import WordCloud
# dict를 넣고 할 경우에는 다음과 같은 처리가 필요
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(front_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 우대 사항에 대한 시각화

# %%
front_tf_idf = get_tfidf(list(df_front.job_add_noun), len(df_front))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(front_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %%
front_tf_idf = get_tfidf(list(df_front.job_due_noun), len(df_front))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(front_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# - 요구사항, 우대 사항에 전체적으로 예상되는 웹 서비스 개발이 주를 이룬다.
# - 특이하게 보이는 단어로 "협업" 단어의 비중이 높아보인다. 개발자에게 협업 비중의 중요성을 강조하는 것으로 추론 가능

# %% [markdown]
# ### 백

# %%
# 요구사항
back_tf_idf = get_tfidf(list(df_back.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(back_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 프론트와는 다르게 서비스, 언어, 대규모, 서버 이런 단어들이 많이 보인다. 조금 더 기술적인 것을 요구하는 것으로 추정
# 역시 팀을 강조하는 것이 보인다. 특히 프론트와 다르게 "백엔드"를 대놓고 강조하는 것이 보인다.

# %%
# 우대사항
back_tf_idf = get_tfidf(list(df_back.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(back_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 이상한 단어가 발견되었는데, 이는 아무래도 공고 기준 특정한 산업군을 요구한 것으로 보인다.
# 혹은 특정 회사의 공고가 많이 추출되었는데 해당 공고에서 특정 산업군의 배경지식을 요구해서 강조된 것으로 보인다.
# 그 외에는 기술, 운영, 서비스, 환경 이라는 단어가 보이는데 환경은 서버 환경 등을 요구한 것으로 추정된다.
# 그 이외에 프론트 대비 프로젝트, 솔루션 등의 단어도 더 보인다.

# %%
# 우대사항
back_tf_idf = get_tfidf(list(df_back.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(back_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 부동산 회사의 공고가 많이 선별된 것으로 보인다. 정확한 분석을 위해서는 백엔드 팀만을 대상으로 뽑아봐야 할 것으로 보이나,
# 그것을 제외하고는 다양한 것이 보인다. 프론트와 대비해서 백의 경우에는 좀 다르다.

# %% [markdown]
# ### 데이터 사이언스

# %%
len(df_ds)
# Out:
# 15

# %% [markdown]
# 공고의 양이 많지는 않지만, 15개의 데이터 정도로 우선 넣어보고 부족할 경우 데이터 사이언스 파트는 수동으로 데이터를 모아서 넣을려고 한다.

# %%
# 자격요건
ds_tf_idf = get_tfidf(list(df_ds.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(ds_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 러닝이라는 단어가 강요되고, 딥/머신이 보이는것으로 보아 ds에서는 딥러닝/머신러닝의 이해도 또한 중요하다. 두 개의 중요도는 유사한 것으로 보인다. (보통 같이 묶여서 쓰이는 것을 통해 알 수 있다. 다른 it 분야에 비해 문제, 지식, 활용 등이 보이는 것으로 보아. 실제 분석 문제의 해결 경험이 중요할 것으로 예측된다.

# %%
# 자격요건
ds_tf_idf = get_tfidf(list(df_ds.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(ds_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 확실히 데이터 사이언티스트는 석사를 많이 요구한다. 그 이외에 대회 입상 경험 등도 중요하며, 통계학 등의 단어도 보이는 것으로 보아 통계학적 이해도 또한 굉장히 중요할 것으로 예측 된다. 신용 이라는 단어는 신용 모델링 관련 분야 공고가 많이 들어있을 것으로 예측할 수 있다.

# %% [markdown]
# ### 경영 직군 분석

# %%
cur_df = df.loc[df.ct_1st == 'Management & Business']
cur_df['ct_2nd'].value_counts().index
# Out:
# Index(['Project Manager', 'Business Support Manager', 'Operations Manager',
#        'Strategic Planner', 'Business Development', 'Accountant',
#        'Service Planner', 'BM・Merchandiser', 'Data Analyst', 'General Affairs',
#        'Secretary', 'Information Security Manager', 'CFO',
#        'Purchasing Manager', 'Office Manager', 'Local Manager',
#        'Organization Management', 'Admin Assistant', 'Finance Manager',
#        'Exhibition Planner', 'Risk Management Specialist', 'Consultant',
#        'Global Business Development Manager',
#        'ISMS (Information Security System)', 'Branch Manager'],
#       dtype='object')

# %% [markdown]
# 주요 직군 2개인 PM, Business Support Manager와 Data Analyst에 대해서 분석하자.

# %%
df_pm = cur_df.loc[cur_df.ct_2nd == 'Project Manager']
df_bsm = cur_df.loc[cur_df.ct_2nd == 'Business Support Manager']
df_da = cur_df.loc[cur_df.ct_2nd == 'Data Analyst']

# %% [markdown]
# ### pm

# %%
# 자격요건
pm_tf_idf = get_tfidf(list(df_pm.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(pm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# IT와는 다르게 고객, 지원, 문서화, 의사결정 등등의 단어가 들어간다. 또한 '이해관계자' 같은 단어도 새로 발견되었다.

# %%
# 우대요건
pm_tf_idf = get_tfidf(list(df_pm.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(pm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 우대사항에도 전략, 고객, 제품 등의 단어가 들어감

# %%
# 업무
pm_tf_idf = get_tfidf(list(df_pm.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(pm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### bsm

# %%
# 자격요건
bsm_tf_idf = get_tfidf(list(df_bsm.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(bsm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 경영 관리의 경우에는 사업, 지원, 회계가 들어간다, 엑셀, 급여 등의 총무 관련 언어도 보이며, 타 직군 대비 "커뮤니케이션" 강조가 들어가다.

# %%
# 우대요건
bsm_tf_idf = get_tfidf(list(df_bsm.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(bsm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 관리, 지원 관련 업무가 보이며, 스타트업이 보인다. 원티드의 특성으로 다수의 스타트업 기업 관리 경험을 요구하는 것으로 추정

# %%
# 우대요건
bsm_tf_idf = get_tfidf(list(df_bsm.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(bsm_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 자금, 회계, 운영, 예산, 세무, 결산 등 회계 관련 경영 용어들이 보인다. 다른 것과 다르게 사업보다는 경영 전반의 업무로 키워드가 다르게 나오는 것으로 추정된다.

# %% [markdown]
# ### da

# %%
# 자격요건
da_tf_idf = get_tfidf(list(df_da.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(da_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 데이터 사이언티스트와 조금 다르게 개선, 활용, 서비스, 추출 커뮤니케이션 등의 단어가 더 보인다.
# 딥러닝, 머신러닝 등의 내용은 보이지 않는다.

# %%
# 우대사항
da_tf_idf = get_tfidf(list(df_da.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(da_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 비즈니스, 마케팅, 분석, 서비스 등의 단어가 조금 더 중요하게 보인다. 통계 등을 보였던 데이터 사이언티스트와는 다른 조합들이다.

# %%
# 주요업무
da_tf_idf = get_tfidf(list(df_da.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(da_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 업무적인 부분도 대시보드, 인사이트, 지표 분석 등으로 이루어져 데이터 사이언티스트와는 다른 업무 영역을 보여주고 있다.

# %% [markdown]
# ## 데이터 직군 해부

# %% [markdown]
# 이 쯤 되면 데이터 사이언티스트, 데이터 엔지니어, 데이터 분석가, 머신러닝 엔지니어 데이터 관련 4개의 직군은 얼마나 차이가 클 지를 조금 더 자세히 보고 싶다. 얼마나 연관성이 있고, 얼마나 차이가 있는지.
# 이를 위해서 4가지 직군의 데이터를 우선 점검하자.

# %%
data_job = ['Data Engineer', 'Machine Learning Engineer', 'Data Scientist', 'Data Analyst']
data_job_df = df.loc[df.ct_2nd.apply(lambda x: True if x in data_job else False)]

# %%
data_job_df.ct_2nd.value_counts()
# Out:
# Data Engineer                103
# Data Analyst                  16
# Machine Learning Engineer     16
# Data Scientist                15
# Name: ct_2nd, dtype: int64

# %% [markdown]
# 먼저 데이터 엔지니어와 머신러닝 엔지니어에 대해서 추가로 분석을 진행해보자.

# %%
df_de = data_job_df.loc[data_job_df.ct_2nd == 'Data Engineer']
df_mle = data_job_df.loc[data_job_df.ct_2nd == 'Machine Learning Engineer']

# %% [markdown]
# ### de

# %%
# 자격요건
de_tf_idf = get_tfidf(list(df_de.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(de_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 생각보다 엔지니어링 관련 단어는 적게 보이나, 개발 구축, 처리 관련 단어가 보인다.
# 작게나마 파이프라인 등의 단어가 들어가 있다.

# %%
# 우대사항
de_tf_idf = get_tfidf(list(df_de.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(de_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 우대사항과 자격요건에 큰 차이가 없다. 다만 "러닝"이 추가된 것으로 보아 딥러닝/머신러닝 기반 관련 지식을 우대로 보는 것으로 보인다. ML/DL 파이프라인 구축을 원하는 것일 가능성이 있다.

# %%
# 주요업무
de_tf_idf = get_tfidf(list(df_de.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(de_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### MLE

# %%
# 자격요건
mle_tf_idf = get_tfidf(list(df_mle.job_req_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(mle_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 데이터 사이언스티스트 대비 모델에 대해 강조하는 비중이 더 늘어났음을 알 수 있다.

# %%
# 우대 사항
mle_tf_idf = get_tfidf(list(df_mle.job_add_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(mle_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 자율 주행 관련 회사가 여기서는 많이 잡힌 것으로 ㅗㅂ인다. 그 이외에는 실시간, 모델, 등이 보이는 거승로 보인다.
# 추가로 자연어 등의 단어도 발견됨

# %%
# 주요 업무
mle_tf_idf = get_tfidf(list(df_mle.job_due_noun), len(df_back))
wordcloud = WordCloud(background_color='white', font_path = font_path).generate_from_frequencies(mle_tf_idf)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# 문제 해결 방법, 모델, 이미지, 개인화, 추천 등이 보인다. 실질적 업무는 사용자 추천이 많이 보이는 것으로 보인다.
